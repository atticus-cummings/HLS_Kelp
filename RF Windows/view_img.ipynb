# %%
import rasterio
import matplotlib.pyplot as plt
import os
from matplotlib.colors import ListedColormap
import re
import csv
from skimage import io
import requests
from PIL import Image
from io import BytesIO

# %%
tile = '11SKU'
location = 'Isla_Vista_Kelp'
path = os.path.join(r'H:LS_data\imagery\Isla_vista_kelp\processed',tile)

#granule = 'HLS.L30.T11SKU.2023040T183427.v2.0'
granules = os.listdir(path)
for granule in granules[20:50]:
    file_data = granule.split('.')
    sensor = file_data[1]
    if(sensor == 'L30'):
        continue
    try:
        files = os.listdir(os.path.join(path,granule))
    except: 
        continue
    metadata_file = [f for f in files if re.search(r'metadata\.csv$', f)]
    if metadata_file :
        with open(os.path.join(path,granule, metadata_file[0]), mode='r') as file:
            csv_reader = csv.reader(file)
            keys = next(csv_reader)  
            values = next(csv_reader) 
        metadata = dict(zip(keys, values))
    print(metadata['SENSING_TIME'])
    urls = metadata['data_vis_url']
    img_urls = urls.strip("[]").replace("'", "").split(", ")
    print(img_urls)
    response = requests.get(img_urls[0])
    img = Image.open(BytesIO(response.content))
    img.show()

# %%
tile = '11SKU'
path = os.path.join(r'H:\HLS_data\imagery\Isla_vista_kelp\processed',tile)
files = os.listdir(path)
training_data = []
cmap = ListedColormap(['red', 'blue', 'green'])
for i, file in enumerate(files):
    with rasterio.open(os.path.join(path, file)) as src:
        training_img = src.read(6)  
        print(file)
        plt.figure(figsize=(10, 10))
        plt.imshow(training_img[2800:3100, 800:1400])
        plt.show()  




# plt.figure(figsize=(6, 6))
# plt.imshow(training_img[6,:], cmap='gray')
# plt.show()
# Out:
# HLS.L30.T11SKU.2017071T183351.v2.0_processed.tif
# HLS.L30.T11SKU.2017087T183342.v2.0_processed.tif
# HLS.L30.T11SKU.2017119T183324.v2.0_processed.tif
# HLS.L30.T11SKU.2017167T183349.v2.0_processed.tif
# HLS.L30.T11SKU.2017263T183416.v2.0_processed.tif
# HLS.L30.T11SKU.2017279T183422.v2.0_processed.tif
# HLS.L30.T11SKU.2017295T183425.v2.0_processed.tif
# HLS.L30.T11SKU.2017311T183423.v2.0_processed.tif
# HLS.L30.T11SKU.2017327T183418.v2.0_processed.tif
# HLS.L30.T11SKU.2019029T183353.v2.0_processed.tif
# HLS.L30.T11SKU.2019077T183342.v2.0_processed.tif
# HLS.L30.T11SKU.2019125T183334.v2.0_processed.tif
# HLS.L30.T11SKU.2019173T183358.v2.0_processed.tif
# HLS.L30.T11SKU.2019205T183406.v2.0_processed.tif
# HLS.L30.T11SKU.2019221T183413.v2.0_processed.tif
# HLS.L30.T11SKU.2019253T183421.v2.0_processed.tif
# HLS.L30.T11SKU.2019269T183427.v2.0_processed.tif
# HLS.L30.T11SKU.2019285T183430.v2.0_processed.tif
# HLS.L30.T11SKU.2019301T183430.v2.0_processed.tif
# HLS.L30.T11SKU.2019349T183424.v2.0_processed.tif
# HLS.L30.T11SKU.2022221T183416.v2.0_processed.tif
# HLS.L30.T11SKU.2022229T183438.v2.0_processed.tif
# HLS.L30.T11SKU.2022237T183420.v2.0_processed.tif
# HLS.L30.T11SKU.2022245T183438.v2.0_processed.tif
# HLS.L30.T11SKU.2022261T183445.v2.0_processed.tif
# HLS.L30.T11SKU.2022269T183428.v2.0_processed.tif
# HLS.L30.T11SKU.2022277T183443.v2.0_processed.tif
# HLS.L30.T11SKU.2022293T183441.v2.0_processed.tif
# HLS.L30.T11SKU.2022309T183445.v2.0_processed.tif
# HLS.L30.T11SKU.2022317T183435.v2.0_processed.tif
# HLS.L30.T11SKU.2022333T183432.v2.0_processed.tif
# HLS.L30.T11SKU.2022341T183439.v2.0_processed.tif
# HLS.L30.T11SKU.2023024T183428.v2.0_processed.tif
# HLS.L30.T11SKU.2023032T183435.v2.0_processed.tif
# HLS.L30.T11SKU.2023040T183427.v2.0_processed.tif
# HLS.L30.T11SKU.2023096T183403.v2.0_processed.tif
# HLS.L30.T11SKU.2023104T183340.v2.0_processed.tif
# HLS.L30.T11SKU.2023112T183357.v2.0_processed.tif
# HLS.L30.T11SKU.2023128T183346.v2.0_processed.tif
# HLS.L30.T11SKU.2023152T183325.v2.0_processed.tif
# HLS.L30.T11SKU.2023168T183335.v2.0_processed.tif
# HLS.L30.T11SKU.2023176T183325.v2.0_processed.tif
# HLS.L30.T11SKU.2023200T183348.v2.0_processed.tif
# HLS.L30.T11SKU.2023208T183344.v2.0_processed.tif
# HLS.L30.T11SKU.2023216T183358.v2.0_processed.tif
# HLS.L30.T11SKU.2023224T183353.v2.0_processed.tif
# HLS.L30.T11SKU.2023240T183402.v2.0_processed.tif
# HLS.L30.T11SKU.2023264T183411.v2.0_processed.tif
# HLS.L30.T11SKU.2023280T183415.v2.0_processed.tif
# HLS.L30.T11SKU.2023288T183421.v2.0_processed.tif
# HLS.L30.T11SKU.2023304T183416.v2.0_processed.tif
# HLS.L30.T11SKU.2023312T183415.v2.0_processed.tif
# HLS.L30.T11SKU.2023320T183418.v2.0_processed.tif
# HLS.L30.T11SKU.2023328T183422.v2.0_processed.tif
# HLS.L30.T11SKU.2023336T183424.v2.0_processed.tif
# HLS.L30.T11SKU.2024003T183422.v2.0_processed.tif
# HLS.L30.T11SKU.2024011T183414.v2.0_processed.tif
# HLS.L30.T11SKU.2024043T183412.v2.0_processed.tif
# HLS.L30.T11SKU.2024059T183406.v2.0_processed.tif
# HLS.L30.T11SKU.2024075T183356.v2.0_processed.tif
# HLS.L30.T11SKU.2024083T183413.v2.0_processed.tif
# HLS.L30.T11SKU.2024099T183405.v2.0_processed.tif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       6 for i, file in enumerate(files):
#       7     with rasterio.open(os.path.join(path, file)) as src:
# ----> 8         training_img = src.read(6)
#       9         print(file)
#      10         plt.figure(figsize=(10, 10))
#
# KeyboardInterrupt:
