# %%
import pandas as pd
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
import os
import pickle
from matplotlib.colors import ListedColormap

# %%
path = r'C:\Users\attic\HLS_Kelp\imagery\rf_classified'
files = os.listdir(path)
training_data = []
cmap = ListedColormap(['red', 'blue', 'green'])
for i, file in enumerate(files):
    with rasterio.open(os.path.join(path, file)) as src:
        training_img = src.read(1)  
        print(file)
        plt.figure(figsize=(6, 6))
        plt.imshow(training_img, cmap=cmap)
        plt.show()  




# plt.figure(figsize=(6, 6))
# plt.imshow(training_img[6,:], cmap='gray')
# plt.show()
# Out:
# HLS.L30.T10SGD.2017071T183415.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2017087T183406.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2017103T183359.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2017135T183357.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2017151T183406.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2017167T183413.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2017199T183422.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2017215T183429.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2017231T183434.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T10SGD.2018074T183404.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T11SKU.2018074T183340.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T11SKU.2018106T183324.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T11SKU.2018122T183316.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.L30.T11SKU.2018170T183303.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018062T184251.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018067T184209.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018072T184141.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018092T183921.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018097T183919.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018102T183931.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018107T183919.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018112T183921.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018117T183919.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018122T183921.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018127T183919.v2.0_rf_ready.tif_kelp_classified.tif
# HLS.S30.T11SKU.2018132T183921.v2.0_rf_ready.tif_kelp_classified.tif
