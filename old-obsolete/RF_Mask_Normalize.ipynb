# %%
import rasterio
from rasterio.warp import calculate_default_transform, reproject, Resampling
import numpy as np
import matplotlib.pyplot as plt
import os
import re
from sklearn.cluster import KMeans
from scipy.ndimage import binary_dilation
from matplotlib.colors import ListedColormap
import matplotlib.colors as mcolors
from rasterio.errors import RasterioIOError

# %%
tile = '10SGD'
location = 'Isla_Vista_Kelp'
save_mask = True
save_classification = True
path = os.path.join(r'C:\Users\attic\HLS_Kelp\imagery',location,tile)

# %%
granules = os.listdir(path)
for item in granules:
    if os.path.isdir(os.path.join(path,item)):
        img_path = os.path.join(path,item)
        granule = item
        break
    else:
        continue
files = os.listdir(img_path)
desired_bands = ['B02','B03','B04','B05','B06','B07'] #2,3,4,5,6,7]

pattern = re.compile(r'\.(' + '|'.join(desired_bands) + r')\.tif$')
img_files = [f for f in files if re.search(pattern, f)]

# print(img_files)
# if '.csv' in img_files[0]:
#     geotiff_path = os.path.join(img_path, img_files[1]) #Geotiff used for aligning DEM 
# else:
#     geotiff_path = os.path.join(img_path, img_files[0])
geotiff_path = os.path.join(img_path, img_files[0])

with rasterio.open(geotiff_path) as dst:   
    hls = dst.read()
    dem_path = r'C:\Users\attic\HLS_Kelp\imagery\Socal_DEM.tiff'
    dem = rasterio.open(dem_path)
    if (dem.crs != dst.crs):
        reprojected_dem = np.zeros((hls.shape[1], hls.shape[2]), dtype=hls.dtype)
        reproject(
            source=dem.read(),
            destination=reprojected_dem,
            src_transform=dem.transform,
            src_crs=dem.crs,
            dst_transform=dst.transform,
            dst_crs=dst.crs,
            resampling=Resampling.bilinear)
    hls_flat = np.squeeze(hls, axis=0)   

if reprojected_dem.any():
    struct = np.ones((5,5))
    land_mask = binary_dilation(reprojected_dem > 0, structure = struct)
    ocean_mask = binary_dilation(reprojected_dem < -60 , structure = struct)
    full_mask = land_mask + ocean_mask
    # plt.figure(figsize=(6, 6))
    # plt.imshow(land_mask, cmap='gray')
    # plt.show()    
    # plt.figure(figsize=(6, 6))
    # plt.imshow(full_mask, cmap='gray')
    # plt.show()
    if save_mask:
        mask_path = os.path.join(path,f'{tile}_fullmask.tif')
        transform = dst.transform  
        height, width = full_mask.shape
        profile = {
            'driver': 'GTiff',
            'width': width,
            'height': height,
            'count': 1,  # one band
            'dtype': rasterio.uint8,  # assuming binary mask, adjust dtype if needed
            'crs': dst.crs,
            'transform': transform,
            'nodata': 0  # assuming no data is 0
        }

        # Write the land mask array to GeoTIFF
        with rasterio.open(mask_path, 'w', **profile) as dst:
            dst.write(full_mask.astype(rasterio.uint8), 1)
else:
    print("Something failed, you better go check...")
for item in granules:
    if os.path.isdir(os.path.join(path,item)):
        img_path = os.path.join(path,item)
        granule = item
    else:
        continue
    files = os.listdir(img_path)
    img_files = [f for f in files if re.search(pattern, f)]
    if not len(img_files)  == 6:
        print(f"incomplete file download: {item}")
        continue
    img_bands = []

    try:
        for file in img_files:
            with rasterio.open(os.path.join(img_path, file)) as src:
                img_bands.append(np.where(full_mask, 0, src.read(1)))  # Create image with the various bands
    except RasterioIOError as e:
        print(f"Error reading file {file} in granule {item}: {e}")
        continue  # Skip to the next granule if a file cannot be read

    img = np.stack(img_bands, axis=0)

    n_bands, height, width = img.shape
    img_2D = img.reshape(img.shape[0], -1).T #classifier takes 2D array of band values for each pixel 

    img_sum = img_2D.sum(axis=1)
    img_2D_normalized  = img_2D / img_sum[:,None] #divide value by sum of pixel band values
    img_2D_normalized = (img_2D_normalized * 255)
    img_2D_normalized = img_2D_normalized.astype(np.uint8)

    if not os.path.isdir (r'C:\Users\attic\HLS_Kelp\imagery\rf_prepped'):
        os.mkdir(r'C:\Users\attic\HLS_Kelp\imagery\rf_prepped')
    classification_path = os.path.join(r'C:\Users\attic\HLS_Kelp\imagery\rf_prepped',f'{granule}_rf_ready.tif')
    transform = dst.transform  
    reshaped_normalized_img = img_2D_normalized.reshape(height, width, 6)
    # print(reshaped_normalized_img.shape)
    # plt.figure(figsize=(10, 10))
    # plt.imshow(reshaped_normalized_img[:,:,3], cmap='gray')
    # plt.show()  

    num_bands = 6
    data_type = rasterio.uint8
    profile = {
        'driver': 'GTiff',
        'width': width,
        'height': height,
        'count': 6,  # one band
        'dtype': data_type,  # assuming binary mask, adjust dtype if needed
        'crs': dst.crs,
        'transform': transform,
        'nodata': 0  # assuming no data is 0
    }
    # Write the land mask array to GeoTIFF
    with rasterio.open(classification_path, 'w', **profile) as dst:
        for i in range(num_bands):
            dst.write(reshaped_normalized_img[:,:,i].astype(data_type), i + 1)
# Out:
# C:\Users\attic\AppData\Local\Temp\ipykernel_22416\3539605092.py:96: RuntimeWarning: divide by zero encountered in divide
#   img_2D_normalized  = img_2D / img_sum[:,None] #divide value by sum of pixel band values
# C:\Users\attic\AppData\Local\Temp\ipykernel_22416\3539605092.py:96: RuntimeWarning: invalid value encountered in divide
#   img_2D_normalized  = img_2D / img_sum[:,None] #divide value by sum of pixel band values
# C:\Users\attic\AppData\Local\Temp\ipykernel_22416\3539605092.py:98: RuntimeWarning: invalid value encountered in cast
#   img_2D_normalized = img_2D_normalized.astype(np.uint8)
# incomplete file download: HLS.L30.T10SGD.2018154T183317.v2.0
# incomplete file download: HLS.L30.T10SGD.2018170T183327.v2.0
# incomplete file download: HLS.L30.T10SGD.2018186T183336.v2.0
# incomplete file download: HLS.L30.T10SGD.2018202T183343.v2.0
# incomplete file download: HLS.L30.T10SGD.2018218T183352.v2.0
# incomplete file download: HLS.L30.T10SGD.2018234T183400.v2.0
# incomplete file download: HLS.L30.T10SGD.2018250T183406.v2.0
# incomplete file download: HLS.L30.T10SGD.2018266T183411.v2.0
# incomplete file download: HLS.L30.T10SGD.2018282T183419.v2.0
# incomplete file download: HLS.L30.T10SGD.2018298T183424.v2.0
# Error reading file HLS.S30.T10SGD.2018067T184209.v2.0.B03.tif in granule HLS.S30.T10SGD.2018067T184209.v2.0: Read or write failed. C:/Users/attic/HLS_Kelp/imagery/Isla_Vista_Kelp/10SGD/HLS.S30.T10SGD.2018067T184209.v2.0/HLS.S30.T10SGD.2018067T184209.v2.0.B03.tif, band 1: IReadBlock failed at X offset 5, Y offset 1: TIFFReadEncodedTile() failed.
# Error reading file HLS.S30.T10SGD.2018077T184059.v2.0.B06.tif in granule HLS.S30.T10SGD.2018077T184059.v2.0: 'C:/Users/attic/HLS_Kelp/imagery/Isla_Vista_Kelp/10SGD/HLS.S30.T10SGD.2018077T184059.v2.0/HLS.S30.T10SGD.2018077T184059.v2.0.B06.tif' not recognized as a supported file format.
# incomplete file download: HLS.S30.T10SGD.2018082T184031.v2.0
# incomplete file download: HLS.S30.T10SGD.2018087T183949.v2.0
# incomplete file download: HLS.S30.T10SGD.2018142T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018147T183919.v2.0
# incomplete file download: HLS.S30.T10SGD.2018152T183931.v2.0
# incomplete file download: HLS.S30.T10SGD.2018157T183929.v2.0
# incomplete file download: HLS.S30.T10SGD.2018162T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018172T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018177T183919.v2.0
# incomplete file download: HLS.S30.T10SGD.2018187T183919.v2.0
# incomplete file download: HLS.S30.T10SGD.2018192T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018197T183929.v2.0
# incomplete file download: HLS.S30.T10SGD.2018202T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018207T184029.v2.0
# incomplete file download: HLS.S30.T10SGD.2018212T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018217T184019.v2.0
# incomplete file download: HLS.S30.T10SGD.2018222T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018227T184019.v2.0
# incomplete file download: HLS.S30.T10SGD.2018232T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018237T183909.v2.0
# incomplete file download: HLS.S30.T10SGD.2018247T184019.v2.0
# incomplete file download: HLS.S30.T10SGD.2018252T183921.v2.0
# incomplete file download: HLS.S30.T10SGD.2018257T183949.v2.0
# incomplete file download: HLS.S30.T10SGD.2018262T184031.v2.0
# incomplete file download: HLS.S30.T10SGD.2018267T184109.v2.0
# incomplete file download: HLS.S30.T10SGD.2018272T184141.v2.0
# incomplete file download: HLS.S30.T10SGD.2018277T184219.v2.0
# incomplete file download: HLS.S30.T10SGD.2018282T184251.v2.0
# incomplete file download: HLS.S30.T10SGD.2018287T184329.v2.0
# incomplete file download: HLS.S30.T10SGD.2018292T184401.v2.0
# incomplete file download: HLS.S30.T10SGD.2018297T184439.v2.0
# incomplete file download: HLS.S30.T10SGD.2018302T184501.v2.0
