# %%
import rasterio
import matplotlib.pyplot as plt

# %%
with rasterio.open(r'C:\Users\attic\HLS_Kelp\imagery\Isla_Vista_Kelp\11SKU\11SKU_landmask.tif') as img:
    image = img.read(1)

plt.figure(figsize=(10, 10))
plt.imshow(image, cmap='gray')
plt.show()
